# %%
from because.probability import prob

from because.synth import read_data
from because.visualization import viz

r = read_data.Reader('/home/arun/HPCC-covid19/LLCP/llcpA.csv')
ds = r.read()

ps = prob.ProbSpace(ds)
print('ps.N = ', ps.N)
print('ps.fieldList = ', ps.fieldList)
print('ds shape = ',len(ps.fieldList))
# Out:
# hbe:  0.9490824254306831
# getData:  301667 records read.
# ps.N =  301667
# ps.fieldList =  ['age', 'gender', 'weight', 'height', 'ageGroup', 'genhealth', 'asthma_ever', 'asthma', 'skincancer', 'othercancer', 'copd', 'arthritis', 'depression', 'kidneydis', 'diabetes', 'maritaldetail', 'married', 'education', 'veteran', 'income', 'state', 'physicalactivity', 'childcnt', 'sleephours', 'employment', 'smokertype', 'bmi', 'bmicat', 'drinks']
# ds shape =  29

# %% [markdown]
# # DIABETES, AGE, HEIGHT, WEIGHT, BMI

# %% [markdown]
# ## Observation 1: Diabetes and Age are positively correlated.
#
# Probability of diabetes increases with the age.
#
# Let's see what is the relaionship between age and height.

# %% [markdown]
# ### Diabetes | Age

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=['age'], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  21.402

# %% [markdown]
# ## Observation 2: Weight and Height are positively correlated.

# %% [markdown]
# ### Weight | Height

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=['weight'], condSpec=['height'], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('weight',)] , Condition =  [('height',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  16.355

# %% [markdown]
# ## Observation 3: Diabetes and Weight are positively correlated.
#
# As weight increases, the probability of diabetes increases.

# %% [markdown]
# ### Diabetes | Weight

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=['weight'], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  11.439

# %% [markdown]
# ## Observation 4: Diabetes and Height are not correlated. (negative but not strong)
#
# As the height increased, the probability of diabetes decreases,
#
# But the corelation factor seems to be small, as the change is not significant.

# %% [markdown]
# ### Diabetes | Height

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=['height'], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('height',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  10.244

# %% [markdown]
# ### Height | Age
#
# Height is somewhat corelated with age.

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=['height'], condSpec=['age'], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('height',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  17.842

# %% [markdown]
# ### Weight | Age

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('weight')], condSpec=['age'], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('age',)] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  48.101
# Viz.show: Target =  [('weight',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  40.565

# %% [markdown]
# ### BMI | Age
#
# It seems that there are few outliers in the data.
#
# Read second graph, arounf weigth 40lbs, there seems to be an abrupt change in the expected value of BMI category.

# %%
viz.show(probspace=ps, targetSpec=['bmi'], condSpec=['age'], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  21.627
# Viz.show: Target =  [('bmicat',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  88.233

# %% [markdown]
# ### Diabetes | Age, Height
#
# Given a particular age, height does not affect the diabetes probability.
#
# And as the probability of diabetes is increases with the age.

# %%
# %matplotlib widget
# %matplotlib widget
# %matplotlib widget
# %matplotlib widget
# %matplotlib widget
# %matplotlib widget

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=['diabetes'], condSpec=[('age'),('height')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes',)] , Condition =  [('age',), ('height',)]
# Viz.show: Showing graph =  3D Expected value plot with two conditions , power =  1
# nTests =  496
# Test Time =  293.334
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age'),('height')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',), ('height',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  496
# Test Time =  0.004
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Diabetes | Age, Weight
#
# Given a particular age, weight and diabetes positively corelated.

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age'),('weight')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',), ('weight',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  992
# Test Time =  53.299
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Observation 5: For a given height, higher the weight, higher the probability of diabetes.
#
# After a particular age, height stops increasing but weight will increase and hence diabetes probability might increase depending on the weight.

# %% [markdown]
# ### Diabetes | Height, Weight

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('height'),('weight')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('height',), ('weight',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  512
# Test Time =  0.004
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## Observation 6: Diabetes and BMI are positively correlated.
#
# As BMI increases, the probability of diabetes increases.

# %% [markdown]
# ### Diabetes | BMI

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=['diabetes'], condSpec=[('bmi')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes',)] , Condition =  [('bmi',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  32.451

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('bmi')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('bmi',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  12.447

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('bmicat')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('bmicat',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  5.249

# %% [markdown]
# ## Observation 7: BMI and Weight are positively correlated.
#
# They should be. as they are directly proportional to each other.

# %% [markdown]
# ### BMI | Weight

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=['bmi'], condSpec=[('weight')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  326.876
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=['bmi'], condSpec=[('weight')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  43.611

# %% [markdown]
# ### BMI | Height
#
# Even though BMI is calculated with height, BMI is not correlated with height.
#
# Second graph shows that the population is mostly under the category of 'overweight'.

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=['bmi'], condSpec=[('height')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('height',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  297.413
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=['bmi'], condSpec=[('height')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('height',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  17.594

# %% [markdown]
# ### Diabetes | BMI, Height

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('height'),('bmi')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('height',), ('bmi',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  480
# Test Time =  0.004
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Diabetes | BMI, Weight

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('weight'),('bmi')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('weight',), ('bmi',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  960
# Test Time =  0.015
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### BMI | Age

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  32.396
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  288.217
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Diabetes | BMI, Age

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age'),('bmi')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',), ('bmi',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  True
# nTests =  930
# Test Time =  677.821
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # DIABETES, INCOME. AGE,

# %% [markdown]
# ## Observation 9: Diabetes and Income are negatively correlated.

# %% [markdown]
# ### Diabetes | Income
#
# As the income increased the probability of diabetes decreased.

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  8.087

# %% [markdown]
# ### Age | Income
#
# As people age, they they tend to have a stable income source, and thereby increase in income.
#
# But at the age of 60, there is a drop, explaining that retirement can reduce the income.

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('age')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('age',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  162.04
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  42.732

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('age')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('age',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  8.076

# %% [markdown]
# ### Diabetes | Age, Income
#
# For people aged 35 and above with higher income tend to have lesser probability of diabetes.
#
# But this is not for the people with the age 35 or below. As people of this age have very less chance of diabetes.

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income'),('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',), ('age',)]
# Viz.show: Showing graph =  3D Bound Probability plot with 2 conditionals. , power =  1
# enhance =  False
# nTests =  248
# Test Time =  0.003
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
ps.fieldList
# Out:
# ['age',
#  'gender',
#  'weight',
#  'height',
#  'ageGroup',
#  'genhealth',
#  'asthma_ever',
#  'asthma',
#  'skincancer',
#  'othercancer',
#  'copd',
#  'arthritis',
#  'depression',
#  'kidneydis',
#  'diabetes',
#  'maritaldetail',
#  'married',
#  'education',
#  'veteran',
#  'income',
#  'state',
#  'physicalactivity',
#  'childcnt',
#  'sleephours',
#  'employment',
#  'smokertype',
#  'bmi',
#  'bmicat',
#  'drinks']

# %%
ps.getValues('employment')
# Out:
# ['1-employed',
#  '2-self-employed',
#  '3-outofwork',
#  '4-homemaker',
#  '5-student',
#  '6-retired',
#  '7-unableToWork',
#  '8-unknown']

# %% [markdown]
# ### Diabetes | Age, Controlled for Income

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[('income')], filtSpec=[], gtype='pdf', power=1, enhance=True)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  16.525

# %% [markdown]
# ### Diabetes | Age, Controlled for Height

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[('height')], filtSpec=[], gtype='pdf', power=1, enhance=True)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=True)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['height']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0

# %% [markdown]
# ### Diabetes | Age, Controlled for Weight

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[('weight')], filtSpec=[], gtype='pdf', power=1, enhance=False)
# viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0

# %% [markdown]
# ### Diabetes | Age, Controlled for BMI

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[('bmi')], filtSpec=[], gtype='pdf', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  73.286
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0

# %% [markdown]
# ### Diabetes | Income, Controlled for Age

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('age')], filtSpec=[], gtype='pdf', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  4.75

# %% [markdown]
# ### Diabetes | Income, Controlled for BMI

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('bmi')], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  1
# Viz.show: Controlling for  ['bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  0.0

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('diabetes')], controlFor=[('bmi')], filtSpec=[], gtype='pdf', power=1, enhance=False)

# %% [markdown]
# ### BMI | Income

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  0.002
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('bmi')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  8.076
# Viz.show: Target =  [('income',)] , Condition =  [('bmi',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  26.896

# %% [markdown]
# ### Weight | Income

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('weight')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('weight')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('weight',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  8.863
# Viz.show: Target =  [('income',)] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  34.641

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('weight')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('weight')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('weight',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  0.002
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Viz.show: Target =  [('income',)] , Condition =  [('weight',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  0.001
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Height | Income

# %%
# %matplotlib widget
viz.show(probspace=ps, targetSpec=[('height')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('height')], controlFor=[], filtSpec=[], gtype='pdf', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('height',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  0.001
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Viz.show: Target =  [('income',)] , Condition =  [('height',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  1
# Controlling for:  [] , power =  1
# Test Time =  0.001
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib inline
viz.show(probspace=ps, targetSpec=[('height')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('height')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('height',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  9.599
# Viz.show: Target =  [('income',)] , Condition =  [('height',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  14.606

# %% [markdown]
# # Finding Income vs Age correlation

# %%
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)

viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('height')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('bmi')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  33.609
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['height']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  42.012
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  111.128
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# ...

# %%
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('height'),('bmi')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('height'),('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('bmi'),('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['height', 'bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  36.33
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['height', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  30.085
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['bmi', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  22.383

# %%
viz.show(probspace=ps, targetSpec=[('income')], condSpec=[('age')], controlFor=[('height'),('bmi'),('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('income',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['height', 'bmi', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  231.328

# %% [markdown]
# # Finding BMI vs Age correlation

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('weight')], filtSpec=[], gtype='exp', power=10, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('income')], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  18.894
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  1
# Viz.show: Controlling for  ['height']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  23.801
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  10
# Viz.show: Controlling for  ['weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  79.176
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# ...

# %%
# viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('weight')], filtSpec=[], gtype='exp', power=10, enhance=False)
# viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('diabetes')], filtSpec=[], gtype='exp', power=1, enhance=False)
# viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('income')], filtSpec=[], gtype='exp', power=1, enhance=False)
# viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('weight'),('diabetes')], filtSpec=[], gtype='exp', power=10, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('weight'),('income')], filtSpec=[], gtype='exp', power=10, enhance=False)
# viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('diabetes'),('income')], filtSpec=[], gtype='exp', power=1, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  10
# Viz.show: Controlling for  ['weight', 'income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  303.838

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('weight'),('diabetes')], filtSpec=[], gtype='exp', power=10, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  10
# Viz.show: Controlling for  ['height', 'weight', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  1037.161

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('weight'),('income')], filtSpec=[], gtype='exp', power=10, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  10
# Viz.show: Controlling for  ['height', 'weight', 'income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  3297.004

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('diabetes'),('income')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'diabetes', 'income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  353.022

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('weight'),('diabetes'),('income')], filtSpec=[], gtype='exp', power=10, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  10
# Viz.show: Controlling for  ['weight', 'diabetes', 'income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  578.473

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('age')], controlFor=[('height'),('weight'),('diabetes'),('income')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('age',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'diabetes', 'income']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  2029.652

# %% [markdown]
# # Finding BMI vs Income correlation

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('weight')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('diabetes')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  7.998
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  20.301
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  18.839
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# ...

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('weight')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('diabetes')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('weight'),('diabetes')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('weight'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('diabetes'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  120.412
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  32.219
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  141.345
# ...

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('weight'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('weight'),('diabetes')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('diabetes'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('weight'),('diabetes'),('age')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  1478.79
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  234.97
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'diabetes', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  280.044
# ...

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('weight'),('age'),('diabetes')], filtSpec=[], gtype='exp', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Expected value plot with single condition , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'age', 'diabetes']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  50
# Elapsed Time =  2706.984

# %%
viz.show(probspace=ps, targetSpec=[('bmi')], condSpec=[('income')], controlFor=[('height'),('weight'),('age'),('diabetes')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('bmi',)] , Condition =  [('income',)]
# Viz.show: Showing graph =  2-variable Probability Distribution plot. , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'age', 'diabetes']
# Controlling for:  ['height', 'weight', 'age', 'diabetes'] , power =  5
# Test Time =  26412.585

# %% [markdown]
# # Finding Diabaetes vs Income correlation

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('weight')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('bmi')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  4.567
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  11.494
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  11.31
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# ...

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('weight')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('bmi')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('bmi'),('weight')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('age'),('weight')], filtSpec=[], gtype='pdf', power=5, enhance=False)
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('bmi'),('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'weight']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  98.629
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  325.648
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  88.557
# ...

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('weight'),('bmi')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  6611.741

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('weight'),('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  1511.404

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('bmi'),('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'bmi', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  4127.474

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('bmi'),('weight'),('age')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['bmi', 'weight', 'age']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
# Test Time =  6159.974

# %%
viz.show(probspace=ps, targetSpec=[('diabetes','yes')], condSpec=[('income')], controlFor=[('height'),('weight'),('age'),('bmi')], filtSpec=[], gtype='pdf', power=5, enhance=False)
# Out:
# Viz.show: Target =  [('diabetes', 'yes')] , Condition =  [('income',)]
# Viz.show: Showing graph =  2D Bound Probability plot with 1 conditional. , power =  5
# Viz.show: Controlling for  ['height', 'weight', 'age', 'bmi']
# Dimensions =  2 .  Conditionals =  1
# Number of points to test for each conditional =  35
